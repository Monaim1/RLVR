# %%
# !pip install openai
# Out:
# Collecting dotenv
#   Downloading dotenv-0.9.9-py2.py3-none-any.whl.metadata (279 bytes)
# Collecting python-dotenv (from dotenv)
#   Using cached python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Downloading dotenv-0.9.9-py2.py3-none-any.whl (1.9 kB)
# Using cached python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv, dotenv
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [dotenv]
# Successfully installed dotenv-0.9.9 python-dotenv-1.1.1

# %%
from openai import OpenAI
import os

openrouter_key = os.getenv("OPENROUTER_API_KEY")

client = OpenAI(
  base_url="https://openrouter.ai/api/v1",

  api_key='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',
)

completion = client.chat.completions.create(
    model="moonshotai/kimi-k2",
    messages=[
        {"role": "user", 
        "content": "What is the meaning of life?"}
    ],
    max_tokens=2000  # keep this below your quota (e.g. 2000, 4000, etc.)
)

print(completion.choices[0].message.content)
# Out:
# I don’t have “the” answer—nobody truly does—but most people find meaning through a few recurring themes:
#
# 1. Connection – deep relationships with family, friends, a partner, or a community tend to top the list.
# 2. Creation – building, inventing, writing, parenting, teaching; anything that leaves a positive trace.
# 3. Growth – learning, overcoming challenges, becoming more capable or wiser than yesterday.
# 4. Service – helping others or a cause bigger than yourself.
# 5. Transcendence – art, faith, or experiences that lift you beyond your ordinary limits.
#
# You can combine any of these in whatever proportion feels right. What matters is that the meaning is something you actively choose, not something you wait to discover.
