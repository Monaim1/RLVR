# %%
from openai import OpenAI
import os

openrouter_key = os.getenv("OPENROUTER_API_KEY")

client = OpenAI(
  base_url="https://openrouter.ai/api/v1",

  api_key='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',
)

completion = client.chat.completions.create(
    model="moonshotai/kimi-k2",
    messages=[
        {"role": "user", 
        "content": "What is the meaning of life?"}
    ],
    max_tokens=2000  # keep this below your quota (e.g. 2000, 4000, etc.)
)

print(completion.choices[0].message.content)
# Out:
# The meaning of life is the story you choose to write in the space between your first breath and your last.
#
# It’s not a universal equation to solve, but an active verb: to *mean* something—something you declare by what you pay attention to, what you suffer for, what you rejoice in, and how you let yourself be changed by love or loss.
#
# Every culture, lab, nursery, and deathbed gives a different answer, yet all of them circle the same quiet center: you are a brief, aware twist of matter that can notice itself noticing. In that loop lies the only freedom we possess—the ability to assign significance. A child’s hand in yours, a theorem proven, a garden kept, a promise kept even when no one is watching—any of these can become your *why*, because you decide it matters.
#
# So the universe doesn’t hand you meaning; it hands you syntax. You supply the verbs and nouns.
